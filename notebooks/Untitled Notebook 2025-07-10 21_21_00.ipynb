# %%
df = spark.table("databricksformula1.default.table_runs")

# %%
df.printSchema()

# %%
df = df.withColumn("run_id", df.run_id.cast("long"))
df = df.withColumn("job_id", df.job_id.cast("long"))
df.display()

# %%
df.drop('id').write.mode('overwrite').option("overwriteSchema", "true").saveAsTable('databricksformula1.default.table_runs_backup')

# %%
# %sql

DROP TABLE databricksformula1.default.table_runs

# %%
# %sql
CREATE table if not exists databricksformula1.default.table_runs (
    id BIGINT GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
    run_id BIGINT,
    job_id BIGINT,
    type_of_run VARCHAR(255),
    created_timestamp TIMESTAMP)

# %%
df = spark.table("databricksformula1.default.table_runs_backup")

# %%
# %sql
select * from databricksformula1.default.table_runs_backup

# %%
df.write.mode('append').saveAsTable('databricksformula1.default.table_runs')

# %%
df = spark.table("databricksformula1.default.table_runs")
df.display()

# %%
# %sql

SELECT * FROM databricksformula1.default.stocks_metadata

# %%
# %sql

SELECT DISTINCT ingestion_date FROM databricksformula1.default.stocks

# %%
# %sql

SELECT * FROM databricksformula1.default.stocks where ingestion_date = '2025-07-10'

# %%
from lib.api_extraction import downlaod_stock
end_date = datetime.today()
start_date = end_date - timedelta(days=40*365)

pdf = downlaod_stock(ticker, start_date, end_date)

# %%
df = spark.table('databricksformula1.default.stocks')

# %%
df = df.withColumn("run_id", df.run_id.cast("long"))
df = df.withColumn("job_id", df.job_id.cast("long"))

# %%
df.write.mode('overwrite').option("overwriteSchema", "true").saveAsTable('databricksformula1.default.stocks')

# %%
df = spark.table('databricksformula1.default.stocks')
df.printSchema()

# %%
df = spark.table('databricksformula1.default.stocks_metadata')

# %%
df = df.withColumn("run_id", df.run_id.cast("long"))
df = df.withColumn("job_id", df.job_id.cast("long"))

# %%
df.write.mode('overwrite').option("overwriteSchema", "true").saveAsTable('databricksformula1.default.stocks_metadata')
